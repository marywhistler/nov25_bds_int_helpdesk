# %% [raw]
# 1. Import Libraries

# %%
import os
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import openpyxl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 6
#       4 import pandas as pd
#       5 import matplotlib.pyplot as plt
# ----> 6 import openpyxl
#
# ModuleNotFoundError: No module named 'openpyxl'

# %% [raw]
# 2. Load Data

# %%
directory = Path("../data/raw/Help Desk Tickets")

issues     = pd.read_csv(directory   / "issues.csv",                low_memory = False)
snapshot   = pd.read_csv(directory   / "issues_snapshot.csv",       low_memory = False)
change     = pd.read_csv(directory   / "issues_change_history.csv", low_memory = False)
utterances = pd.read_csv(directory   / "sample_utterances.csv",     low_memory = False)
rated      = pd.read_excel(directory / "issues_snapshot_sample.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniforge3/envs/helpdesk/lib/python3.12/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~/miniforge3/envs/helpdesk/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %% [raw]
# 3. Overview over Datasets

# %%
print("ISSUES:\nColumns:",     issues.shape[1],     "\nRows:", issues.shape[0],     "\nVariables:", ", ".join(issues.columns),     "\n")
display(issues.head(3))
print("SNAPSHOT:\nColumns:",   snapshot.shape[1],   "\nRows:", snapshot.shape[0],   "\nVariables:", ", ".join(snapshot.columns),   "\n")
display(snapshot.head(3))
print("CHANGE:\nColumns:",     change.shape[1],     "\nRows:", change.shape[0],     "\nVariables:", ", ".join(change.columns),     "\n")
display(change.head(3))
print("UTTERANCES:\nColumns:", utterances.shape[1], "\nRows:", utterances.shape[0], "\nVariables:", ", ".join(utterances.columns), "\n")
display(utterances.head(3))
print("RATED:\nColumns:",      rated.shape[1],      "\nRows:", rated.shape[0],      "\nVariables:", ", ".join(rated.columns),      "\n")
display(rated.head(3))
